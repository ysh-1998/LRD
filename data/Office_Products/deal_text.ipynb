# %%
import gzip
import pandas as pd
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def get_df(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')
meta_df = get_df("/home/ysh/project/KDA_LRD/data/Office/meta_Office_Products.json.gz")
meta_df
# Out:
#               asin                                        description  price  \
# 0       0078800242                All in one TeacherWorks Plus CD-ROM  93.06
# 1       0113000316  High quality inkjet cartridges use high-densit...    NaN
# 2       043928631X  Harry Potter living bookmark showing Harry, He...    NaN
# 3       0439340039                       Windows based computer game.    NaN
# 4       0439394058  126 pieces: 23" tall schoolhouse calendar, 12 ...  11.64
# ...            ...                                                ...    ...
# 134833  B00LQZE5C2  Lightahead LA-7555 Clear document Folder. Made...   7.99
# 134834  B00LQZE9BE  Lightahead LA-7552 Expanding Clear File with 1...   5.99
# 134835  B00LSYQC7C  Friend Chips is the hottest new trading and co...    NaN
# 134836  BT008G9O8G  Continuous Length Removable Paper Label 2-3/7"...  29.66
# 134837  BT008G9O9A                    0.5" - Diameter - 1200 Label(s)  16.95
#
#                                                     imUrl  \
# 0       http://ecx.images-amazon.com/images/I/41K1aBkl...
# 1       http://ecx.images-amazon.com/images/I/51AMwP3D...
# 2       http://ecx.images-amazon.com/images/I/41SulB7T...
# 3       http://ecx.images-amazon.com/images/I/51zQE0w%...
# 4       http://ecx.images-amazon.com/images/I/51DFp0Lg...
# ...                                                   ...
# 134833  http://ecx.images-amazon.com/images/I/31UXXGe7...
# 134834  http://ecx.images-amazon.com/images/I/31kB8Foi...
# 134835  http://ecx.images-amazon.com/images/I/61DZSNSQ...
# 134836  http://ecx.images-amazon.com/images/I/41SFeM42...
# 134837  http://ecx.images-amazon.com/images/I/41nN5t%2...
#
#                                                   related  \
# 0                   {'buy_after_viewing': ['007861970X']}
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       {'also_bought': ['B000QE1HHU', 'B00207MG4Y', '...
# ...                                                   ...
# 134833                                                NaN
# 134834                                                NaN
# 134835                    {'also_viewed': ['B00LV1MMX0']}
# 134836  {'also_bought': ['B0081TZD54', 'B0002VS66W', '...
# 134837  {'also_bought': ['B0002VS6HG', 'B0002VS6HQ', '...
#
#                   salesRank  \
# 0       {'Software': 18529}
# 1                       NaN
# 2                       NaN
# 3       {'Software': 32784}
# 4                       NaN
# ...                     ...
# 134833                  NaN
# 134834                  NaN
# 134835                  NaN
# 134836                  NaN
# 134837                  NaN
#
#                                                categories  \
# 0       [[Office Products, Office & School Supplies, C...
# 1       [[Office Products, Office & School Supplies, P...
# 2       [[Office Products, Office & School Supplies, L...
# 3       [[Office Products, Office & School Supplies, E...
# 4       [[Office Products, Office & School Supplies, E...
# ...                                                   ...
# 134833  [[Office Products, Office & School Supplies, F...
# 134834  [[Office Products, Office & School Supplies, F...
# 134835  [[Office Products, Office & School Supplies, F...
# 134836  [[Office Products, Office & School Supplies, L...
# 134837  [[Office Products, Office & School Supplies, L...
#
#                                                     title       brand
# 0                                                     NaN         NaN
# 1       123GetInk -14-pack 5-black 3-cyan 3-magenta 3-...         NaN
# 2       Harry Potter Lenticular Hologram Bookmark - Ha...         NaN
# 3                                                     NaN         NaN
# 4       Scholastic SC939405 All-In-One Schoolhouse Cal...  Scholastic
# ...                                                   ...         ...
# 134833  Lightahead&reg; LA-7555 Clear document Folder,...         NaN
# 134834  Lightahead&reg; LA-7552 Expanding file Folder ...         NaN
# 134835  Friend Chips Trading and Collecting Game, 4 Ch...         NaN
# 134836                        Cont  Removable Paper Label     Brother
# 134837                      1/2&quot;  Round Paper Labels     Brother
#
# [134838 rows x 9 columns]

# %%
import re
import html
def clean_text(text):
    text = html.unescape(text)
    text = re.sub(r'["\n\r]*', '', text)
    return text
outf = open("/home/ysh/project/KDA_LRD/data/Office/Office.title.text", "w")
with open("/home/ysh/project/KDA_LRD/data/Office/Office.text") as f:
    lines = f.readlines()[1:]
    for line in lines:
        item_id = line.split("\t")[0]
        # print(item_id)
        categories = meta_df[meta_df['asin'] == item_id]['categories']
        if len(categories) > 0:
            for cate in categories:
                if cate[0][0] == "Office Products":
                    category = clean_text(cate[0][-1])
                    break
            outf.write(item_id+"\t"+category + "\n")
        else:
            outf.write(item_id+"\t"+"" + "\n")
